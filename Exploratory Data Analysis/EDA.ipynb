# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sn

# %%
# load dataset
tip = sn.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# load dataset
diamond = sn.load_dataset("diamonds")
diamond
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
tip.describe(exclude = 'number')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tip.value_counts(normalize = True)
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       0.008197
# 3.07        1.00   Female  Yes     Sat   Dinner  1       0.004098
# 22.23       5.00   Male    No      Sun   Dinner  2       0.004098
# 20.69       2.45   Female  No      Sat   Dinner  4       0.004098
#             5.00   Male    No      Sun   Dinner  5       0.004098
#                                                            ...
# 15.53       3.00   Male    Yes     Sat   Dinner  2       0.004098
# 15.69       1.50   Male    Yes     Sun   Dinner  2       0.004098
#             3.00   Male    Yes     Sat   Dinner  3       0.004098
# 15.77       2.23   Female  No      Sat   Dinner  2       0.004098
# 50.81       10.00  Male    Yes     Sat   Dinner  3       0.004098
# Name: proportion, Length: 243, dtype: float64

# %%
sn.kdeplot(data = tip, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sn.displot(data=tip, x= 'total_bill' )

# %%
sn.displot(data = tip , x = 'total_bill', col = 'sex')
# Out:
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
sn.displot(data = tip , x = 'total_bill', kde = True)

# %%
sn.countplot(data=diamond , x = 'cut')
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
plt.pie(tip.smoker.value_counts(),labels = ['NO', 'yES'], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2d44a4c0620>,
# ...
#  [Text(-0.4012471747910624, 1.0242073543585746, 'NO'),
#   Text(0.4012470788978477, -1.024207391926042, 'yES')],
#  [Text(-0.2188620953405795, 0.5586585569228588, '61.89%'),
#   Text(0.21886204303518964, -0.5586585774142045, '38.11%')])

# %%
sn.lineplot(data = tip , x = 'size' , y = 'tip' )
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
#slustred bar
sn.barplot(data=tip, x='day' ,y = 'total_bill', hue = 'sex')
# Out:
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sn.histplot(diamond.sort_values('clarity').reset_index(), x = 'clarity' , hue = 'cut' , alpha = 0.6, multiple = 'dodge')
# Out:
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\aymna\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
sn.barplot(data = diamond, x = 'color', y = 'price')
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
sn.scatterplot(data = tip, x = 'total_bill', y = 'tip' , hue = 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
